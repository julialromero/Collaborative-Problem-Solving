# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # Define File Paths

# %%
RQA_DIR = "/Users/angelina/Dropbox (Emotive Computing)/CPS_Gaze_Fixations/RQA/"
MASTERFILE = RQA_DIR + "CPS2_Gaze_All_Participants_Masterfile_TimeSeries.csv"
ALL_PP = "/Users/angelina/Dropbox (Emotive Computing)/CPS_Gaze_Fixations/utils/All_PP.csv"
RAW_OUTPUTDIR = RQA_DIR + "MdRQA_Time_Series/RAW/"
FIX_OUTPUTDIR = RQA_DIR + "MdRQA_Time_Series/FIXATIONS/"
TIMESERIES_DIR = RQA_DIR + "Participant_Block_225ms_Time_Series/"

# %% [markdown]
# # Import Masterfile

# %%
# Read in the All_PP file which is our source of truth for the complete teams (2 participants) and their PIDs
dfAll_PP = pd.read_csv(ALL_PP)

# Read in masterfile which contains one row per participant + block and filepaths to each file we need
dfMaster = pd.read_csv(MASTERFILE)

dfMaster['Analyze'] = np.where(dfMaster['ParticipantBlock'] == "CPS2-CU-T60-PB-Transfer", "no", dfMaster['Analyze'])
dfMaster['Analyze'] = np.where(dfMaster['ParticipantBlock'] == "CPS2-CU-T29-PC-Transfer", "no", dfMaster['Analyze'])
dfMaster['Analyze'] = np.where(dfMaster['ParticipantBlock'] == "CPS2-CU-T27-PA-Transfer", "no", dfMaster['Analyze'])

dfMasterSelected = dfMaster.loc[dfMaster['Analyze'] == 'yes']
dfMasterSelected.reset_index(drop=True, inplace=True)

# Informational
print("Number of unique team + blocks in All_PP: ", len(dfAll_PP.groupby(['GROUPID', 'block'])))
print("Number of unique team + blocks in Masterfile: ", len(dfMasterSelected['GROUPID_block'].unique()))
print("Number of participant + blocks in Masterfile: ", len(dfMasterSelected))
# Out:
# Number of unique team + blocks in All_PP:  274
# Number of unique team + blocks in Masterfile:  582
# Number of participant + blocks in Masterfile:  1516
# /var/folders/mk/d16gbl2n2mj9x5gptkp92y5c0000gn/T/ipykernel_6193/3879428115.py:2: DtypeWarning: Columns (21,22,23,24,25,26,30,31,32,36) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfAll_PP = pd.read_csv(ALL_PP)

# %%
# Group by team, block, and participant(GROUPID represents a unique team because it is specific to a school)
all_pp_team_block_pids = dfAll_PP.groupby(['GROUPID', 'block', 'participant_id'], \
                                          as_index=False).size()[['GROUPID', 'block', 'participant_id']]
all_pp_team_block_pids.rename(columns={"block": "Block", "participant_id": "pid"}, inplace=True)


# Merge Master w/ All_PP to filter teams we should not process
## NOTE: Team 1094 gets filtered from All_PP file because there is no gaze data (result is 271 team + blocks)
team_blocks = pd.merge(all_pp_team_block_pids, dfMasterSelected[['GROUPID', 'Block', 'pid']], \
                       on=['GROUPID', 'Block', 'pid'], how='inner')

# %%
print(len(team_blocks.groupby(['GROUPID', 'Block'])))
print(len(team_blocks.groupby(['GROUPID'])))
# Out:
# 271
# 93

# %% [markdown]
# # Generate MdRQA Team Time Series

# %%
# Group by team, block, and participant(GROUPID represents a unique team because it is specific to a school)
all_pp_team_block_pids = dfAll_PP.groupby(['GROUPID', 'block', 'participant_id'], \
                                          as_index=False).size()[['GROUPID', 'block', 'participant_id']]
all_pp_team_block_pids.rename(columns={"block": "Block", "participant_id": "pid"}, inplace=True)


# Merge Master w/ All_PP to filter teams we should not process
## NOTE: Team 1094 gets filtered from All_PP file because there is no gaze data (result is 271 team + blocks)
team_blocks = pd.merge(all_pp_team_block_pids, dfMasterSelected[['GROUPID', 'Block', 'pid']], \
                       on=['GROUPID', 'Block', 'pid'], how='inner')

# Get number of participants in each team 
## NOTE: Before filtering, in the Masterfile we have teams of sizes 1, 2, 3, and 4. 
##       Now, teams should only be size 3
team_sizes = team_blocks.groupby(['GROUPID', 'Block']).size().reset_index(name='num_participants')

# Add on number of participants
team_blocks = pd.merge(team_blocks, team_sizes, on=['GROUPID', 'Block'], how='inner')

# Add on time series file paths
team_blocks = pd.merge(team_blocks, dfMasterSelected[['GROUPID', 'Block', 'pid', \
                                                      '225ms-time-series-RAW', '225ms-time-series-FIXATIONS']], \
                       on=['GROUPID', 'Block', 'pid'], how='inner')

# Group by filtered team and block (GROUPID represents a unique team because it is specific to a school)
grp_team_block = team_blocks.groupby(['GROUPID', 'Block'])

num_nan = 0
num_total = 0
# Iterate through each team and block to create their MdRQA time series
team_block_cnt = 0
for team_block,_ in grp_team_block:
    team_block_cnt += 1
    GROUPID = team_block[0]
    block = team_block[1]
    print("Processing Team %d: %s %s" % (team_block_cnt, str(GROUPID), block))
    
    # Create MdRQA time series DataFrames
    MdRQA_raw = pd.DataFrame()
    MdRQA_fix = pd.DataFrame()

        
    # Get time series of all participants
    all_raw_time_series = team_blocks.loc[(team_blocks['GROUPID'] == GROUPID) & \
                                          (team_blocks['Block'] == block), '225ms-time-series-RAW']
    
    all_fix_time_series = team_blocks.loc[(team_blocks['GROUPID'] == GROUPID) & \
                                          (team_blocks['Block'] == block), '225ms-time-series-FIXATIONS']
    
    
    # Add all time series to an MdRQA DataFrame
    for i,raw_time_series_filepath in enumerate(all_raw_time_series):
        raw_time_series = pd.read_csv(TIMESERIES_DIR + raw_time_series_filepath)
        raw_time_series = raw_time_series['grid_loc'].rename('p'+str(i+1))

        MdRQA_raw = pd.concat([MdRQA_raw, raw_time_series], axis=1)
        
        num_nan += raw_time_series.isna().sum()
        num_total += len(raw_time_series)


    for j,fix_time_series_filepath in enumerate(all_fix_time_series):
        fix_time_series = pd.read_csv(TIMESERIES_DIR + fix_time_series_filepath)
        fix_time_series = fix_time_series['grid_loc'].rename('p'+str(j+1))

        MdRQA_fix = pd.concat([MdRQA_fix, fix_time_series], axis=1)

    # Save MdRQA DataFrames as csv files
    filename = str(GROUPID) + "-" + block + "_"
#     MdRQA_raw.to_csv(RAW_OUTPUTDIR + filename + "RAW.csv", index=False)
#     MdRQA_fix.to_csv(FIX_OUTPUTDIR + filename + "FIXATIONS.csv", index=False)
    print("\tMdRQA files generated.")


print("All files generated.")
print("Num NaN: ", num_nan)
print("Num total time steps: ", num_total)
# Out:
# Processing Team 1: 1010 ExpBlock1
# 	MdRQA files generated.
# Processing Team 2: 1010 ExpBlock2
# 	MdRQA files generated.
# Processing Team 3: 1020 ExpBlock1
# 	MdRQA files generated.
# Processing Team 4: 1020 ExpBlock2
# 	MdRQA files generated.
# Processing Team 5: 1020 Warmup
# 	MdRQA files generated.
# Processing Team 6: 1024 ExpBlock1
# 	MdRQA files generated.
# Processing Team 7: 1024 ExpBlock2
# 	MdRQA files generated.
# Processing Team 8: 1024 Warmup
# 	MdRQA files generated.
# Processing Team 9: 1025 ExpBlock1
# 	MdRQA files generated.
# Processing Team 10: 1025 ExpBlock2
# 	MdRQA files generated.
# Processing Team 11: 1025 Warmup
# 	MdRQA files generated.
# Processing Team 12: 1032 ExpBlock1
# 	MdRQA files generated.
# Processing Team 13: 1032 ExpBlock2
# 	MdRQA files generated.
# Processing Team 14: 1032 Warmup
# 	MdRQA files generated.
# Processing Team 15: 1034 ExpBlock1
# 	MdRQA files generated.
# Processing Team 16: 1034 ExpBlock2
# 	MdRQA files generated.
# Processing Team 17: 1034 Warmup
# 	MdRQA files generated.
# Processing Team 18: 1035 ExpBlock1
# 	MdRQA files generated.
# Processing Team 19: 1035 ExpBlock2
# 	MdRQA files generated.
# Processing Team 20: 1035 Warmup
# 	MdRQA files generated.
# Processing Team 21: 1036 ExpBlock1
# 	MdRQA files generated.
# Processing Team 22: 1036 ExpBlock2
# 	MdRQA files generated.
# Processing Team 23: 1036 Warmup
# 	MdRQA files generated.
# Processing Team 24: 1037 ExpBlock1
# 	MdRQA files generated.
# Processing Team 25: 1037 ExpBlock2
# 	MdRQA files generated.
# Processing Team 26: 1037 Warmup
# 	MdRQA files generated.
# Processing Team 27: 1038 ExpBlock1
# 	MdRQA files generated.
# Processing Team 28: 1038 ExpBlock2
# 	MdRQA files generated.
# Processing Team 29: 1038 Warmup
# 	MdRQA files generated.
# Processing Team 30: 1039 ExpBlock1
# 	MdRQA files generated.
# Processing Team 31: 1039 ExpBlock2
# 	MdRQA files generated.
# Processing Team 32: 1039 Warmup
# 	MdRQA files generated.
# Processing Team 33: 1040 ExpBlock1
# 	MdRQA files generated.
# Processing Team 34: 1040 ExpBlock2
# 	MdRQA files generated.
# Processing Team 35: 1040 Warmup
# 	MdRQA files generated.
# Processing Team 36: 1041 ExpBlock1
# 	MdRQA files generated.
# Processing Team 37: 1041 ExpBlock2
# 	MdRQA files generated.
# Processing Team 38: 1041 Warmup
# 	MdRQA files generated.
# Processing Team 39: 1042 ExpBlock1
# 	MdRQA files generated.
# Processing Team 40: 1042 ExpBlock2
# 	MdRQA files generated.
# Processing Team 41: 1042 Warmup
# 	MdRQA files generated.
# Processing Team 42: 1043 ExpBlock1
# 	MdRQA files generated.
# Processing Team 43: 1043 ExpBlock2
# 	MdRQA files generated.
# Processing Team 44: 1043 Warmup
# 	MdRQA files generated.
# Processing Team 45: 1044 ExpBlock1
# 	MdRQA files generated.
# Processing Team 46: 1044 ExpBlock2
# 	MdRQA files generated.
# Processing Team 47: 1044 Warmup
# 	MdRQA files generated.
# Processing Team 48: 1045 ExpBlock1
# 	MdRQA files generated.
# Processing Team 49: 1045 ExpBlock2
# 	MdRQA files generated.
# Processing Team 50: 1045 Warmup
# 	MdRQA files generated.
# Processing Team 51: 1046 ExpBlock1
# 	MdRQA files generated.
# Processing Team 52: 1046 ExpBlock2
# 	MdRQA files generated.
# Processing Team 53: 1046 Warmup
# 	MdRQA files generated.
# Processing Team 54: 1047 ExpBlock1
# 	MdRQA files generated.
# Processing Team 55: 1047 ExpBlock2
# 	MdRQA files generated.
# Processing Team 56: 1047 Warmup
# 	MdRQA files generated.
# Processing Team 57: 1050 ExpBlock1
# 	MdRQA files generated.
# Processing Team 58: 1050 ExpBlock2
# 	MdRQA files generated.
# Processing Team 59: 1050 Warmup
# 	MdRQA files generated.
# Processing Team 60: 1051 ExpBlock1
# 	MdRQA files generated.
# Processing Team 61: 1051 ExpBlock2
# 	MdRQA files generated.
# Processing Team 62: 1051 Warmup
# 	MdRQA files generated.
# Processing Team 63: 1052 ExpBlock1
# 	MdRQA files generated.
# Processing Team 64: 1052 ExpBlock2
# 	MdRQA files generated.
# Processing Team 65: 1052 Warmup
# 	MdRQA files generated.
# Processing Team 66: 1054 ExpBlock1
# 	MdRQA files generated.
# Processing Team 67: 1054 Warmup
# 	MdRQA files generated.
# Processing Team 68: 1056 ExpBlock1
# 	MdRQA files generated.
# Processing Team 69: 1056 ExpBlock2
# 	MdRQA files generated.
# Processing Team 70: 1056 Warmup
# 	MdRQA files generated.
# Processing Team 71: 1059 ExpBlock1
# 	MdRQA files generated.
# Processing Team 72: 1059 ExpBlock2
# 	MdRQA files generated.
# Processing Team 73: 1059 Warmup
# 	MdRQA files generated.
# Processing Team 74: 1060 ExpBlock1
# 	MdRQA files generated.
# Processing Team 75: 1060 ExpBlock2
# 	MdRQA files generated.
# Processing Team 76: 1060 Warmup
# 	MdRQA files generated.
# Processing Team 77: 1061 ExpBlock1
# 	MdRQA files generated.
# Processing Team 78: 1061 ExpBlock2
# 	MdRQA files generated.
# Processing Team 79: 1061 Warmup
# 	MdRQA files generated.
# Processing Team 80: 1062 ExpBlock1
# 	MdRQA files generated.
# Processing Team 81: 1062 ExpBlock2
# 	MdRQA files generated.
# Processing Team 82: 1062 Warmup
# 	MdRQA files generated.
# Processing Team 83: 1067 ExpBlock1
# 	MdRQA files generated.
# Processing Team 84: 1067 ExpBlock2
# 	MdRQA files generated.
# Processing Team 85: 1067 Warmup
# 	MdRQA files generated.
# Processing Team 86: 1068 ExpBlock1
# 	MdRQA files generated.
# Processing Team 87: 1068 ExpBlock2
# 	MdRQA files generated.
# Processing Team 88: 1068 Warmup
# 	MdRQA files generated.
# Processing Team 89: 1069 ExpBlock1
# 	MdRQA files generated.
# Processing Team 90: 1069 ExpBlock2
# 	MdRQA files generated.
# Processing Team 91: 1069 Warmup
# 	MdRQA files generated.
# Processing Team 92: 1070 ExpBlock1
# 	MdRQA files generated.
# Processing Team 93: 1070 ExpBlock2
# 	MdRQA files generated.
# Processing Team 94: 1070 Warmup
# 	MdRQA files generated.
# Processing Team 95: 1071 ExpBlock1
# 	MdRQA files generated.
# Processing Team 96: 1071 ExpBlock2
# 	MdRQA files generated.
# Processing Team 97: 1071 Warmup
# 	MdRQA files generated.
# Processing Team 98: 1072 ExpBlock1
# 	MdRQA files generated.
# Processing Team 99: 1072 Warmup
# 	MdRQA files generated.
# Processing Team 100: 1074 ExpBlock1
# 	MdRQA files generated.
# Processing Team 101: 1074 ExpBlock2
# 	MdRQA files generated.
# Processing Team 102: 1074 Warmup
# 	MdRQA files generated.
# Processing Team 103: 1075 ExpBlock1
# 	MdRQA files generated.
# Processing Team 104: 1075 ExpBlock2
# 	MdRQA files generated.
# Processing Team 105: 1075 Warmup
# 	MdRQA files generated.
# Processing Team 106: 1076 ExpBlock1
# 	MdRQA files generated.
# Processing Team 107: 1076 ExpBlock2
# 	MdRQA files generated.
# Processing Team 108: 1077 ExpBlock1
# 	MdRQA files generated.
# Processing Team 109: 1077 ExpBlock2
# 	MdRQA files generated.
# Processing Team 110: 1078 ExpBlock1
# 	MdRQA files generated.
# Processing Team 111: 1078 ExpBlock2
# 	MdRQA files generated.
# Processing Team 112: 1078 Warmup
# 	MdRQA files generated.
# Processing Team 113: 1080 ExpBlock1
# 	MdRQA files generated.
# Processing Team 114: 1080 ExpBlock2
# 	MdRQA files generated.
# Processing Team 115: 1080 Warmup
# 	MdRQA files generated.
# Processing Team 116: 1083 ExpBlock1
# 	MdRQA files generated.
# Processing Team 117: 1083 ExpBlock2
# 	MdRQA files generated.
# Processing Team 118: 1083 Warmup
# 	MdRQA files generated.
# Processing Team 119: 1084 ExpBlock1
# 	MdRQA files generated.
# Processing Team 120: 1084 ExpBlock2
# 	MdRQA files generated.
# Processing Team 121: 1084 Warmup
# 	MdRQA files generated.
# Processing Team 122: 1086 ExpBlock1
# 	MdRQA files generated.
# Processing Team 123: 1086 ExpBlock2
# 	MdRQA files generated.
# Processing Team 124: 1086 Warmup
# 	MdRQA files generated.
# Processing Team 125: 1087 ExpBlock1
# 	MdRQA files generated.
# Processing Team 126: 1087 ExpBlock2
# 	MdRQA files generated.
# Processing Team 127: 1087 Warmup
# 	MdRQA files generated.
# Processing Team 128: 1089 ExpBlock1
# 	MdRQA files generated.
# Processing Team 129: 1089 ExpBlock2
# 	MdRQA files generated.
# Processing Team 130: 1089 Warmup
# 	MdRQA files generated.
# Processing Team 131: 1090 ExpBlock1
# 	MdRQA files generated.
# Processing Team 132: 1090 ExpBlock2
# 	MdRQA files generated.
# Processing Team 133: 1090 Warmup
# 	MdRQA files generated.
# Processing Team 134: 1091 ExpBlock1
# 	MdRQA files generated.
# Processing Team 135: 1091 ExpBlock2
# 	MdRQA files generated.
# Processing Team 136: 1091 Warmup
# 	MdRQA files generated.
# Processing Team 137: 1093 ExpBlock1
# 	MdRQA files generated.
# Processing Team 138: 1093 ExpBlock2
# 	MdRQA files generated.
# Processing Team 139: 1093 Warmup
# 	MdRQA files generated.
# Processing Team 140: 1096 ExpBlock1
# 	MdRQA files generated.
# Processing Team 141: 1096 ExpBlock2
# 	MdRQA files generated.
# Processing Team 142: 1096 Warmup
# 	MdRQA files generated.
# Processing Team 143: 1097 ExpBlock1
# 	MdRQA files generated.
# Processing Team 144: 1097 ExpBlock2
# 	MdRQA files generated.
# Processing Team 145: 1097 Warmup
# 	MdRQA files generated.
# Processing Team 146: 1098 ExpBlock1
# 	MdRQA files generated.
# Processing Team 147: 1098 ExpBlock2
# 	MdRQA files generated.
# Processing Team 148: 1098 Warmup
# 	MdRQA files generated.
# Processing Team 149: 1099 ExpBlock1
# 	MdRQA files generated.
# Processing Team 150: 1099 ExpBlock2
# 	MdRQA files generated.
# Processing Team 151: 1099 Warmup
# 	MdRQA files generated.
# Processing Team 152: 2014 ExpBlock1
# 	MdRQA files generated.
# Processing Team 153: 2014 ExpBlock2
# 	MdRQA files generated.
# Processing Team 154: 2014 Warmup
# 	MdRQA files generated.
# Processing Team 155: 2015 ExpBlock1
# 	MdRQA files generated.
# Processing Team 156: 2015 ExpBlock2
# 	MdRQA files generated.
# Processing Team 157: 2015 Warmup
# 	MdRQA files generated.
# Processing Team 158: 2016 ExpBlock1
# 	MdRQA files generated.
# Processing Team 159: 2016 ExpBlock2
# 	MdRQA files generated.
# Processing Team 160: 2016 Warmup
# 	MdRQA files generated.
# Processing Team 161: 2018 ExpBlock1
# 	MdRQA files generated.
# Processing Team 162: 2018 ExpBlock2
# 	MdRQA files generated.
# Processing Team 163: 2018 Warmup
# 	MdRQA files generated.
# Processing Team 164: 2019 ExpBlock1
# 	MdRQA files generated.
# Processing Team 165: 2019 ExpBlock2
# 	MdRQA files generated.
# Processing Team 166: 2019 Warmup
# 	MdRQA files generated.
# Processing Team 167: 2020 ExpBlock1
# 	MdRQA files generated.
# Processing Team 168: 2020 ExpBlock2
# 	MdRQA files generated.
# Processing Team 169: 2020 Warmup
# 	MdRQA files generated.
# Processing Team 170: 2027 ExpBlock1
# 	MdRQA files generated.
# Processing Team 171: 2027 ExpBlock2
# 	MdRQA files generated.
# Processing Team 172: 2027 Warmup
# 	MdRQA files generated.
# Processing Team 173: 2029 ExpBlock1
# 	MdRQA files generated.
# Processing Team 174: 2029 ExpBlock2
# 	MdRQA files generated.
# Processing Team 175: 2029 Warmup
# 	MdRQA files generated.
# Processing Team 176: 2030 ExpBlock1
# 	MdRQA files generated.
# Processing Team 177: 2030 ExpBlock2
# 	MdRQA files generated.
# Processing Team 178: 2030 Warmup
# 	MdRQA files generated.
# Processing Team 179: 2031 ExpBlock1
# 	MdRQA files generated.
# Processing Team 180: 2031 ExpBlock2
# 	MdRQA files generated.
# Processing Team 181: 2031 Warmup
# 	MdRQA files generated.
# Processing Team 182: 2033 ExpBlock1
# 	MdRQA files generated.
# Processing Team 183: 2033 ExpBlock2
# 	MdRQA files generated.
# Processing Team 184: 2033 Warmup
# 	MdRQA files generated.
# Processing Team 185: 2034 ExpBlock2
# 	MdRQA files generated.
# Processing Team 186: 2034 Warmup
# 	MdRQA files generated.
# Processing Team 187: 2035 ExpBlock1
# 	MdRQA files generated.
# Processing Team 188: 2035 ExpBlock2
# 	MdRQA files generated.
# Processing Team 189: 2035 Warmup
# 	MdRQA files generated.
# Processing Team 190: 2036 ExpBlock1
# 	MdRQA files generated.
# Processing Team 191: 2036 ExpBlock2
# 	MdRQA files generated.
# Processing Team 192: 2036 Warmup
# 	MdRQA files generated.
# Processing Team 193: 2037 ExpBlock1
# 	MdRQA files generated.
# Processing Team 194: 2037 ExpBlock2
# 	MdRQA files generated.
# Processing Team 195: 2037 Warmup
# 	MdRQA files generated.
# Processing Team 196: 2038 ExpBlock1
# 	MdRQA files generated.
# Processing Team 197: 2038 ExpBlock2
# 	MdRQA files generated.
# Processing Team 198: 2038 Warmup
# 	MdRQA files generated.
# Processing Team 199: 2039 ExpBlock1
# 	MdRQA files generated.
# Processing Team 200: 2039 ExpBlock2
# 	MdRQA files generated.
# Processing Team 201: 2039 Warmup
# 	MdRQA files generated.
# Processing Team 202: 2040 ExpBlock1
# 	MdRQA files generated.
# Processing Team 203: 2040 ExpBlock2
# 	MdRQA files generated.
# Processing Team 204: 2040 Warmup
# 	MdRQA files generated.
# Processing Team 205: 2043 ExpBlock1
# 	MdRQA files generated.
# Processing Team 206: 2043 ExpBlock2
# 	MdRQA files generated.
# Processing Team 207: 2043 Warmup
# 	MdRQA files generated.
# Processing Team 208: 2044 ExpBlock1
# 	MdRQA files generated.
# Processing Team 209: 2044 ExpBlock2
# 	MdRQA files generated.
# Processing Team 210: 2044 Warmup
# 	MdRQA files generated.
# Processing Team 211: 2045 ExpBlock1
# 	MdRQA files generated.
# Processing Team 212: 2045 ExpBlock2
# 	MdRQA files generated.
# Processing Team 213: 2045 Warmup
# 	MdRQA files generated.
# Processing Team 214: 2046 ExpBlock1
# 	MdRQA files generated.
# Processing Team 215: 2046 ExpBlock2
# 	MdRQA files generated.
# Processing Team 216: 2046 Warmup
# 	MdRQA files generated.
# Processing Team 217: 2048 ExpBlock1
# 	MdRQA files generated.
# Processing Team 218: 2048 ExpBlock2
# 	MdRQA files generated.
# Processing Team 219: 2048 Warmup
# 	MdRQA files generated.
# Processing Team 220: 2049 ExpBlock1
# 	MdRQA files generated.
# Processing Team 221: 2049 ExpBlock2
# 	MdRQA files generated.
# Processing Team 222: 2052 ExpBlock1
# 	MdRQA files generated.
# Processing Team 223: 2052 ExpBlock2
# 	MdRQA files generated.
# Processing Team 224: 2052 Warmup
# 	MdRQA files generated.
# Processing Team 225: 2053 ExpBlock1
# 	MdRQA files generated.
# Processing Team 226: 2053 ExpBlock2
# 	MdRQA files generated.
# Processing Team 227: 2053 Warmup
# 	MdRQA files generated.
# Processing Team 228: 2054 ExpBlock1
# 	MdRQA files generated.
# Processing Team 229: 2054 ExpBlock2
# 	MdRQA files generated.
# Processing Team 230: 2054 Warmup
# 	MdRQA files generated.
# Processing Team 231: 2056 ExpBlock1
# 	MdRQA files generated.
# Processing Team 232: 2056 ExpBlock2
# 	MdRQA files generated.
# Processing Team 233: 2056 Warmup
# 	MdRQA files generated.
# Processing Team 234: 2057 ExpBlock1
# 	MdRQA files generated.
# Processing Team 235: 2057 ExpBlock2
# 	MdRQA files generated.
# Processing Team 236: 2057 Warmup
# 	MdRQA files generated.
# Processing Team 237: 2060 ExpBlock1
# 	MdRQA files generated.
# Processing Team 238: 2060 ExpBlock2
# 	MdRQA files generated.
# Processing Team 239: 2060 Warmup
# 	MdRQA files generated.
# Processing Team 240: 2062 ExpBlock1
# 	MdRQA files generated.
# Processing Team 241: 2062 ExpBlock2
# 	MdRQA files generated.
# Processing Team 242: 2062 Warmup
# 	MdRQA files generated.
# Processing Team 243: 2063 ExpBlock1
# 	MdRQA files generated.
# Processing Team 244: 2063 ExpBlock2
# 	MdRQA files generated.
# Processing Team 245: 2063 Warmup
# 	MdRQA files generated.
# Processing Team 246: 2066 ExpBlock1
# 	MdRQA files generated.
# Processing Team 247: 2066 ExpBlock2
# 	MdRQA files generated.
# Processing Team 248: 2066 Warmup
# 	MdRQA files generated.
# Processing Team 249: 2068 ExpBlock1
# 	MdRQA files generated.
# Processing Team 250: 2068 ExpBlock2
# 	MdRQA files generated.
# Processing Team 251: 2068 Warmup
# 	MdRQA files generated.
# Processing Team 252: 2069 ExpBlock1
# 	MdRQA files generated.
# Processing Team 253: 2069 ExpBlock2
# 	MdRQA files generated.
# Processing Team 254: 2069 Warmup
# 	MdRQA files generated.
# Processing Team 255: 2070 ExpBlock1
# 	MdRQA files generated.
# Processing Team 256: 2070 ExpBlock2
# 	MdRQA files generated.
# Processing Team 257: 2070 Warmup
# 	MdRQA files generated.
# Processing Team 258: 2071 ExpBlock1
# 	MdRQA files generated.
# Processing Team 259: 2071 ExpBlock2
# 	MdRQA files generated.
# Processing Team 260: 2071 Warmup
# 	MdRQA files generated.
# Processing Team 261: 10100 ExpBlock1
# 	MdRQA files generated.
# Processing Team 262: 10100 ExpBlock2
# 	MdRQA files generated.
# Processing Team 263: 10102 ExpBlock1
# 	MdRQA files generated.
# Processing Team 264: 10102 ExpBlock2
# 	MdRQA files generated.
# Processing Team 265: 10102 Warmup
# 	MdRQA files generated.
# Processing Team 266: 10103 ExpBlock1
# 	MdRQA files generated.
# Processing Team 267: 10103 ExpBlock2
# 	MdRQA files generated.
# Processing Team 268: 10103 Warmup
# 	MdRQA files generated.
# Processing Team 269: 10104 ExpBlock1
# 	MdRQA files generated.
# Processing Team 270: 10104 ExpBlock2
# 	MdRQA files generated.
# Processing Team 271: 10104 Warmup
# 	MdRQA files generated.
# All files generated.
# Num NaN:  657589
# Num total time steps:  3252000

# %% [markdown]
# ## File stats to consider

# %%
# Group by team and block (GROUPID represents a unique team because it is specific to a school)
grp_team_block = dfMasterSelected.groupby(['GROUPID', 'Block'])

# for grp_name, grp in grp_team_block:
#     print(grp_name)

team_sizes = grp_team_block.size().reset_index(name='counts')

print("Group stats:\n")

display(team_sizes)

display(team_sizes.groupby('counts').size().reset_index(name='num_teams'))

# team_sizes.to_csv(OUTPUTDIR + "team_sizes.csv", index=False)
# Out:
# Group stats:
#      GROUPID      Block  counts
# 0       1010  ExpBlock1       3
# 1       1010  ExpBlock2       3
# 2       1010   Transfer       3
# 3       1010     Warmup       3
# 4       1011  ExpBlock1       1
# ..       ...        ...     ...
# 577    10104     Warmup       3
# 578    10105  ExpBlock1       2
# 579    10105  ExpBlock2       2
# 580    10105   Transfer       2
# 581    10105     Warmup       2
#
# [582 rows x 3 columns]
#    counts  num_teams
# 0       1         64
# 1       2        155
# 2       3        310
# 3       4         53

# %%
# Group by team and block (GROUPID represents a unique team because it is specific to a school)
grp_team_block = dfMasterSelected.groupby(['GROUPID', 'Block'])

# Get number of participants in each team
## NOTE: We have teams of sizes 1, 2, 3, and 4
team_sizes = grp_team_block.size().reset_index(name='num_participants')

# Map each team with the team size and its participants
cols = ['GROUPID', 'Block', 'pid', '225ms-time-series-RAW', '225ms-time-series-FIXATIONS']
teams_to_participants = pd.merge(team_sizes, dfMasterSelected[cols], on=['GROUPID', 'Block'])

# Iterate through each team to create their MdRQA time series
team_cnt = 0
for team_block,_ in grp_team_block:
    team_cnt += 1
    GROUPID = team_block[0]
    block = team_block[1]
    print("Processing Team %d: %s %s" % (team_cnt, str(GROUPID), block))
    
    # Create MdRQA time series DataFrames
    MdRQA_raw = pd.DataFrame()
    MdRQA_fix = pd.DataFrame()

    # Check the size of the team (should be 3 or 4)
    if team_sizes.loc[(team_sizes['GROUPID'] == GROUPID) & \
                      (team_sizes['Block'] == block), 'num_participants'].values[0] >= 3:
        
        # Get time series of all participants
        all_raw_time_series = dfMasterSelected.loc[(dfMasterSelected['GROUPID'] == GROUPID) & \
                                                    (dfMasterSelected['Block'] == block), '225ms-time-series-RAW']
        
        all_fix_time_series = dfMasterSelected.loc[(dfMasterSelected['GROUPID'] == GROUPID) & \
                                                     (dfMasterSelected['Block'] == block), '225ms-time-series-FIXATIONS']
        
        # Add all time series to an MdRQA DataFrame
        for i,raw_time_series_filepath in enumerate(all_raw_time_series):
            raw_time_series = pd.read_csv(TIMESERIES_DIR + raw_time_series_filepath)
            raw_time_series = raw_time_series['grid_loc'].rename('p'+str(i+1))
            
            MdRQA_raw = pd.concat([MdRQA_raw, raw_time_series], axis=1)

        
        for j,fix_time_series_filepath in enumerate(all_fix_time_series):
            fix_time_series = pd.read_csv(TIMESERIES_DIR + fix_time_series_filepath)
            fix_time_series = fix_time_series['grid_loc'].rename('p'+str(j+1))
            
            MdRQA_fix = pd.concat([MdRQA_fix, fix_time_series], axis=1)
            
        # Save MdRQA DataFrames as csv files
        filename = str(GROUPID) + "-" + block + "_"
        MdRQA_raw.to_csv(RAW_OUTPUTDIR + filename + "RAW.csv", index=False)
        MdRQA_fix.to_csv(FIX_OUTPUTDIR + filename + "FIXATIONS.csv", index=False)
        print("\tMdRQA files generated.")

print("All files generated.")
